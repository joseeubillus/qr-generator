# %%
# !pip install qrcode
# Out:
# ...
#      |████████████████████████████████| 43 kB 635 kB/s
# ...
#   Created wheel for qrcode: filename=qrcode-7.3.1-py3-none-any.whl size=40401 sha256=1028cc30a00114b7a7be4c80fe6df5b0fb53e01088375ad6d4ec41a43b0b56ac
#   Stored in directory: /root/.cache/pip/wheels/93/d7/39/a4111be2cfb8e679938aa671a37888b6afb1f9e7d748e94492
# Successfully built qrcode
# ...

# %%
import qrcode
from PIL import Image

# %%
#generador qr
#Ingrese link del qr aqui
data=("https://www.linkedin.com/in/joseeduardoubillus/")
#Ingrese el nombre con que quiera que se descargue el archivo
filename="JEUBILLUS.png"
img=qrcode.make(data)
img.save(filename)

# %%
from google.colab import files
files.download(filename)
